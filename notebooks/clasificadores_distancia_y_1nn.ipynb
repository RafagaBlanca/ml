# %%
import sys
sys.path.append("../src")

# %%
import pandas as pd
from preprocess import min_max_scaler

# Cargar el dataset Glass
glass_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/glass/glass.data"
glass_columns = ["Id", "RI", "Na", "Mg", "Al", "Si", "K", "Ca", "Ba", "Fe", "Type"]
glass_df = pd.read_csv(glass_url, names=glass_columns, header=None)
glass_features = glass_df.drop(columns=["Id", "Type"])
glass_target = glass_df["Type"]

# Normalizar el Glass Dataset
glass_features_normalized = min_max_scaler(glass_features.values.tolist())
glass_data_normalized = pd.DataFrame(glass_features_normalized, columns=glass_features.columns)
glass_data_normalized["Type"] = glass_target

# Cargar el dataset Iris
iris_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
iris_columns = ["SepalLength", "SepalWidth", "PetalLength", "PetalWidth", "Class"]
iris_df = pd.read_csv(iris_url, names=iris_columns, header=None)
iris_features = iris_df.drop(columns=["Class"])
iris_target = iris_df["Class"].map({
    "Iris-setosa": 0,
    "Iris-versicolor": 1,
    "Iris-virginica": 2
})

# Normalizar el Iris Dataset
iris_features_normalized = min_max_scaler(iris_features.values.tolist())
iris_data_normalized = pd.DataFrame(iris_features_normalized, columns=iris_features.columns)
iris_data_normalized["Class"] = iris_target

# Cargar el dataset Wine
wine_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data"
wine_columns = ["Class", "Alcohol", "MalicAcid", "Ash", "Alcalinity", "Magnesium", "Phenols",
                "Flavanoids", "NonFlavanoids", "Proanthocyanins", "Color", "Hue",
                "Dilution", "Proline"]
wine_df = pd.read_csv(wine_url, names=wine_columns, header=None)
wine_features = wine_df.drop(columns=["Class"])
wine_target = wine_df["Class"]

# Normalizar el Wine Dataset
wine_features_normalized = min_max_scaler(wine_features.values.tolist())
wine_data_normalized = pd.DataFrame(wine_features_normalized, columns=wine_features.columns)
wine_data_normalized["Class"] = wine_target

# Verificar los datasets normalizados
print("Glass Dataset Preprocesado:")
print(glass_data_normalized.head())

print("\nIris Dataset Preprocesado:")
print(iris_data_normalized.head())

print("\nWine Dataset Preprocesado:")
print(wine_data_normalized.head())
# Out:
# Glass Dataset Preprocesado:
#          RI        Na        Mg        Al        Si         K        Ca   Ba  \
# 0  0.432836  0.437594  1.000000  0.252336  0.351786  0.009662  0.308550  0.0
# 1  0.283582  0.475188  0.801782  0.333333  0.521429  0.077295  0.223048  0.0
# 2  0.220808  0.421053  0.790646  0.389408  0.567857  0.062802  0.218401  0.0
# 3  0.285777  0.372932  0.821826  0.311526  0.500000  0.091787  0.259294  0.0
# 4  0.275241  0.381955  0.806236  0.295950  0.583929  0.088567  0.245353  0.0
#
#     Fe  Type
# 0  0.0     1
# 1  0.0     1
# 2  0.0     1
# 3  0.0     1
# 4  0.0     1
#
# Iris Dataset Preprocesado:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Class
# 0     0.222222    0.625000     0.067797    0.041667      0
# 1     0.166667    0.416667     0.067797    0.041667      0
# 2     0.111111    0.500000     0.050847    0.041667      0
# 3     0.083333    0.458333     0.084746    0.041667      0
# 4     0.194444    0.666667     0.067797    0.041667      0
#
# Wine Dataset Preprocesado:
#     Alcohol  MalicAcid       Ash  Alcalinity  Magnesium   Phenols  Flavanoids  \
# 0  0.842105   0.191700  0.572193    0.257732   0.619565  0.627586    0.573840
# 1  0.571053   0.205534  0.417112    0.030928   0.326087  0.575862    0.510549
# 2  0.560526   0.320158  0.700535    0.412371   0.336957  0.627586    0.611814
# 3  0.878947   0.239130  0.609626    0.319588   0.467391  0.989655    0.664557
# 4  0.581579   0.365613  0.807487    0.536082   0.521739  0.627586    0.495781
#
#    NonFlavanoids  Proanthocyanins     Color       Hue  Dilution   Proline  \
# 0       0.283019         0.593060  0.372014  0.455285  0.970696  0.561341
# 1       0.245283         0.274448  0.264505  0.463415  0.780220  0.550642
# 2       0.320755         0.757098  0.375427  0.447154  0.695971  0.646933
# 3       0.207547         0.558360  0.556314  0.308943  0.798535  0.857347
# 4       0.490566         0.444795  0.259386  0.455285  0.608059  0.325963
#
#    Class
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
from validation import hold_out
from collections import Counter

# Hold-Out para el Glass Dataset
X_glass = glass_data_normalized.drop(columns=["Type"]).values.tolist()
y_glass = glass_data_normalized["Type"].values.tolist()

X_train_glass, X_test_glass, y_train_glass, y_test_glass = hold_out(
    X_glass, y_glass, test_size=0.3, stratify=True, random_seed=42
)
print("Hold-Out Glass Dataset:")
print(f"  Tamaño de entrenamiento: {len(X_train_glass)}, Tamaño de prueba: {len(X_test_glass)}")
print(f"  Distribución de clases (entrenamiento): {Counter(y_train_glass)}")
print(f"  Distribución de clases (prueba): {Counter(y_test_glass)}")

# Hold-Out para el Iris Dataset
X_iris = iris_data_normalized.drop(columns=["Class"]).values.tolist()
y_iris = iris_data_normalized["Class"].values.tolist()

X_train_iris, X_test_iris, y_train_iris, y_test_iris = hold_out(
    X_iris, y_iris, test_size=0.3, stratify=True, random_seed=42
)
print("\nHold-Out Iris Dataset:")
print(f"  Tamaño de entrenamiento: {len(X_train_iris)}, Tamaño de prueba: {len(X_test_iris)}")
print(f"  Distribución de clases (entrenamiento): {Counter(y_train_iris)}")
print(f"  Distribución de clases (prueba): {Counter(y_test_iris)}")

# Hold-Out para el Wine Dataset
X_wine = wine_data_normalized.drop(columns=["Class"]).values.tolist()
y_wine = wine_data_normalized["Class"].values.tolist()

X_train_wine, X_test_wine, y_train_wine, y_test_wine = hold_out(
    X_wine, y_wine, test_size=0.3, stratify=True, random_seed=42
)
print("\nHold-Out Wine Dataset:")
print(f"  Tamaño de entrenamiento: {len(X_train_wine)}, Tamaño de prueba: {len(X_test_wine)}")
print(f"  Distribución de clases (entrenamiento): {Counter(y_train_wine)}")
print(f"  Distribución de clases (prueba): {Counter(y_test_wine)}")
# Out:
# Hold-Out Glass Dataset:
#   Tamaño de entrenamiento: 153, Tamaño de prueba: 61
#   Distribución de clases (entrenamiento): Counter({2: 54, 1: 49, 7: 21, 3: 12, 5: 10, 6: 7})
#   Distribución de clases (prueba): Counter({2: 22, 1: 21, 7: 8, 3: 5, 5: 3, 6: 2})
#
# Hold-Out Iris Dataset:
#   Tamaño de entrenamiento: 105, Tamaño de prueba: 45
#   Distribución de clases (entrenamiento): Counter({0: 35, 1: 35, 2: 35})
#   Distribución de clases (prueba): Counter({0: 15, 1: 15, 2: 15})
#
# Hold-Out Wine Dataset:
#   Tamaño de entrenamiento: 126, Tamaño de prueba: 52
#   Distribución de clases (entrenamiento): Counter({2: 50, 1: 42, 3: 34})
#   Distribución de clases (prueba): Counter({2: 21, 1: 17, 3: 14})

# %%
from validation import k_fold_cross_validation

# K-Fold para el Glass Dataset
folds_glass = k_fold_cross_validation(X_glass, y_glass, k=10, stratify=True, random_seed=42)
print("K-Fold Glass Dataset:")
for i, (X_train, X_val, y_train, y_val) in enumerate(folds_glass, 1):
    print(f"  Fold {i}:")
    print(f"    Tamaño de entrenamiento: {len(X_train)}, Tamaño de validación: {len(X_val)}")
    print(f"    Distribución de clases (entrenamiento): {Counter(y_train)}")
    print(f"    Distribución de clases (validación): {Counter(y_val)}")

# K-Fold para el Iris Dataset
folds_iris = k_fold_cross_validation(X_iris, y_iris, k=10, stratify=True, random_seed=42)
print("\nK-Fold Iris Dataset:")
for i, (X_train, X_val, y_train, y_val) in enumerate(folds_iris, 1):
    print(f"  Fold {i}:")
    print(f"    Tamaño de entrenamiento: {len(X_train)}, Tamaño de validación: {len(X_val)}")
    print(f"    Distribución de clases (entrenamiento): {Counter(y_train)}")
    print(f"    Distribución de clases (validación): {Counter(y_val)}")

# K-Fold para el Wine Dataset
folds_wine = k_fold_cross_validation(X_wine, y_wine, k=10, stratify=True, random_seed=42)
print("\nK-Fold Wine Dataset:")
for i, (X_train, X_val, y_train, y_val) in enumerate(folds_wine, 1):
    print(f"  Fold {i}:")
    print(f"    Tamaño de entrenamiento: {len(X_train)}, Tamaño de validación: {len(X_val)}")
    print(f"    Distribución de clases (entrenamiento): {Counter(y_train)}")
    print(f"    Distribución de clases (validación): {Counter(y_val)}")
# Out:
# K-Fold Glass Dataset:
#   Fold 1:
#     Tamaño de entrenamiento: 162, Tamaño de validación: 18
#     Distribución de clases (entrenamiento): Counter({1: 63, 2: 63, 7: 18, 3: 9, 5: 9})
#     Distribución de clases (validación): Counter({1: 7, 2: 7, 7: 2, 3: 1, 5: 1})
#   Fold 2:
#     Tamaño de entrenamiento: 162, Tamaño de validación: 18
#     Distribución de clases (entrenamiento): Counter({1: 63, 2: 63, 7: 18, 3: 9, 5: 9})
#     Distribución de clases (validación): Counter({1: 7, 2: 7, 7: 2, 3: 1, 5: 1})
#   Fold 3:
#     Tamaño de entrenamiento: 162, Tamaño de validación: 18
#     Distribución de clases (entrenamiento): Counter({1: 63, 2: 63, 7: 18, 3: 9, 5: 9})
#     Distribución de clases (validación): Counter({1: 7, 2: 7, 7: 2, 3: 1, 5: 1})
#   Fold 4:
#     Tamaño de entrenamiento: 162, Tamaño de validación: 18
#     Distribución de clases (entrenamiento): Counter({1: 63, 2: 63, 7: 18, 3: 9, 5: 9})
#     Distribución de clases (validación): Counter({1: 7, 2: 7, 7: 2, 3: 1, 5: 1})
#   Fold 5:
#     Tamaño de entrenamiento: 162, Tamaño de validación: 18
#     Distribución de clases (entrenamiento): Counter({1: 63, 2: 63, 7: 18, 3: 9, 5: 9})
#     Distribución de clases (validación): Counter({1: 7, 2: 7, 7: 2, 3: 1, 5: 1})
#   Fold 6:
#     Tamaño de entrenamiento: 162, Tamaño de validación: 18
#     Distribución de clases (entrenamiento): Counter({1: 63, 2: 63, 7: 18, 3: 9, 5: 9})
#     Distribución de clases (validación): Counter({1: 7, 2: 7, 7: 2, 3: 1, 5: 1})
#   Fold 7:
#     Tamaño de entrenamiento: 162, Tamaño de validación: 18
#     Distribución de clases (entrenamiento): Counter({1: 63, 2: 63, 7: 18, 3: 9, 5: 9})
#     Distribución de clases (validación): Counter({1: 7, 2: 7, 7: 2, 3: 1, 5: 1})
#   Fold 8:
#     Tamaño de entrenamiento: 162, Tamaño de validación: 18
#     Distribución de clases (entrenamiento): Counter({1: 63, 2: 63, 7: 18, 3: 9, 5: 9})
#     Distribución de clases (validación): Counter({1: 7, 2: 7, 7: 2, 3: 1, 5: 1})
#   Fold 9:
#     Tamaño de entrenamiento: 162, Tamaño de validación: 18
#     Distribución de clases (entrenamiento): Counter({1: 63, 2: 63, 7: 18, 3: 9, 5: 9})
#     Distribución de clases (validación): Counter({1: 7, 2: 7, 7: 2, 3: 1, 5: 1})
#   Fold 10:
#     Tamaño de entrenamiento: 162, Tamaño de validación: 18
#     Distribución de clases (entrenamiento): Counter({1: 63, 2: 63, 7: 18, 3: 9, 5: 9})
#     Distribución de clases (validación): Counter({1: 7, 2: 7, 7: 2, 3: 1, 5: 1})
#
# K-Fold Iris Dataset:
#   Fold 1:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Distribución de clases (entrenamiento): Counter({0: 45, 1: 45, 2: 45})
#     Distribución de clases (validación): Counter({0: 5, 1: 5, 2: 5})
#   Fold 2:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Distribución de clases (entrenamiento): Counter({0: 45, 1: 45, 2: 45})
#     Distribución de clases (validación): Counter({0: 5, 1: 5, 2: 5})
#   Fold 3:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Distribución de clases (entrenamiento): Counter({0: 45, 1: 45, 2: 45})
#     Distribución de clases (validación): Counter({0: 5, 1: 5, 2: 5})
#   Fold 4:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Distribución de clases (entrenamiento): Counter({0: 45, 1: 45, 2: 45})
#     Distribución de clases (validación): Counter({0: 5, 1: 5, 2: 5})
#   Fold 5:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Distribución de clases (entrenamiento): Counter({0: 45, 1: 45, 2: 45})
#     Distribución de clases (validación): Counter({0: 5, 1: 5, 2: 5})
#   Fold 6:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Distribución de clases (entrenamiento): Counter({0: 45, 1: 45, 2: 45})
#     Distribución de clases (validación): Counter({0: 5, 1: 5, 2: 5})
#   Fold 7:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Distribución de clases (entrenamiento): Counter({0: 45, 1: 45, 2: 45})
#     Distribución de clases (validación): Counter({0: 5, 1: 5, 2: 5})
#   Fold 8:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Distribución de clases (entrenamiento): Counter({0: 45, 1: 45, 2: 45})
#     Distribución de clases (validación): Counter({0: 5, 1: 5, 2: 5})
#   Fold 9:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Distribución de clases (entrenamiento): Counter({0: 45, 1: 45, 2: 45})
#     Distribución de clases (validación): Counter({0: 5, 1: 5, 2: 5})
#   Fold 10:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Distribución de clases (entrenamiento): Counter({0: 45, 1: 45, 2: 45})
#     Distribución de clases (validación): Counter({0: 5, 1: 5, 2: 5})
#
# K-Fold Wine Dataset:
#   Fold 1:
#     Tamaño de entrenamiento: 144, Tamaño de validación: 16
#     Distribución de clases (entrenamiento): Counter({2: 63, 1: 45, 3: 36})
#     Distribución de clases (validación): Counter({2: 7, 1: 5, 3: 4})
#   Fold 2:
#     Tamaño de entrenamiento: 144, Tamaño de validación: 16
#     Distribución de clases (entrenamiento): Counter({2: 63, 1: 45, 3: 36})
#     Distribución de clases (validación): Counter({2: 7, 1: 5, 3: 4})
#   Fold 3:
#     Tamaño de entrenamiento: 144, Tamaño de validación: 16
#     Distribución de clases (entrenamiento): Counter({2: 63, 1: 45, 3: 36})
#     Distribución de clases (validación): Counter({2: 7, 1: 5, 3: 4})
#   Fold 4:
#     Tamaño de entrenamiento: 144, Tamaño de validación: 16
#     Distribución de clases (entrenamiento): Counter({2: 63, 1: 45, 3: 36})
#     Distribución de clases (validación): Counter({2: 7, 1: 5, 3: 4})
#   Fold 5:
#     Tamaño de entrenamiento: 144, Tamaño de validación: 16
#     Distribución de clases (entrenamiento): Counter({2: 63, 1: 45, 3: 36})
#     Distribución de clases (validación): Counter({2: 7, 1: 5, 3: 4})
#   Fold 6:
#     Tamaño de entrenamiento: 144, Tamaño de validación: 16
#     Distribución de clases (entrenamiento): Counter({2: 63, 1: 45, 3: 36})
#     Distribución de clases (validación): Counter({2: 7, 1: 5, 3: 4})
#   Fold 7:
#     Tamaño de entrenamiento: 144, Tamaño de validación: 16
#     Distribución de clases (entrenamiento): Counter({2: 63, 1: 45, 3: 36})
#     Distribución de clases (validación): Counter({2: 7, 1: 5, 3: 4})
#   Fold 8:
#     Tamaño de entrenamiento: 144, Tamaño de validación: 16
#     Distribución de clases (entrenamiento): Counter({2: 63, 1: 45, 3: 36})
#     Distribución de clases (validación): Counter({2: 7, 1: 5, 3: 4})
#   Fold 9:
#     Tamaño de entrenamiento: 144, Tamaño de validación: 16
#     Distribución de clases (entrenamiento): Counter({2: 63, 1: 45, 3: 36})
#     Distribución de clases (validación): Counter({2: 7, 1: 5, 3: 4})
#   Fold 10:
#     Tamaño de entrenamiento: 144, Tamaño de validación: 16
#     Distribución de clases (entrenamiento): Counter({2: 63, 1: 45, 3: 36})
#     Distribución de clases (validación): Counter({2: 7, 1: 5, 3: 4})

# %%
from validation import leave_one_out

# Leave-One-Out para el Glass Dataset
folds_glass_loo = leave_one_out(X_glass, y_glass)
print("Leave-One-Out Glass Dataset:")
print(f"  Número total de iteraciones: {len(folds_glass_loo)}")
for i, (X_train, X_val, y_train, y_val) in enumerate(folds_glass_loo[:5], 1):  # Mostrar solo las primeras 5 iteraciones
    print(f"  Iteración {i}:")
    print(f"    Tamaño de entrenamiento: {len(X_train)}, Tamaño de validación: {len(X_val)}")
    print(f"    Distribución de clases (entrenamiento): {Counter(y_train)}")
    print(f"    Clase de validación: {y_val[0]}")

# Leave-One-Out para el Iris Dataset
folds_iris_loo = leave_one_out(X_iris, y_iris)
print("\nLeave-One-Out Iris Dataset:")
print(f"  Número total de iteraciones: {len(folds_iris_loo)}")
for i, (X_train, X_val, y_train, y_val) in enumerate(folds_iris_loo[:5], 1):  # Mostrar solo las primeras 5 iteraciones
    print(f"  Iteración {i}:")
    print(f"    Tamaño de entrenamiento: {len(X_train)}, Tamaño de validación: {len(X_val)}")
    print(f"    Distribución de clases (entrenamiento): {Counter(y_train)}")
    print(f"    Clase de validación: {y_val[0]}")

# Leave-One-Out para el Wine Dataset
folds_wine_loo = leave_one_out(X_wine, y_wine)
print("\nLeave-One-Out Wine Dataset:")
print(f"  Número total de iteraciones: {len(folds_wine_loo)}")
for i, (X_train, X_val, y_train, y_val) in enumerate(folds_wine_loo[:5], 1):  # Mostrar solo las primeras 5 iteraciones
    print(f"  Iteración {i}:")
    print(f"    Tamaño de entrenamiento: {len(X_train)}, Tamaño de validación: {len(X_val)}")
    print(f"    Distribución de clases (entrenamiento): {Counter(y_train)}")
    print(f"    Clase de validación: {y_val[0]}")
# Out:
# Leave-One-Out Glass Dataset:
#   Número total de iteraciones: 214
#   Iteración 1:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Distribución de clases (entrenamiento): Counter({2: 76, 1: 69, 7: 29, 3: 17, 5: 13, 6: 9})
#     Clase de validación: 1
#   Iteración 2:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Distribución de clases (entrenamiento): Counter({2: 76, 1: 69, 7: 29, 3: 17, 5: 13, 6: 9})
#     Clase de validación: 1
#   Iteración 3:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Distribución de clases (entrenamiento): Counter({2: 76, 1: 69, 7: 29, 3: 17, 5: 13, 6: 9})
#     Clase de validación: 1
#   Iteración 4:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Distribución de clases (entrenamiento): Counter({2: 76, 1: 69, 7: 29, 3: 17, 5: 13, 6: 9})
#     Clase de validación: 1
#   Iteración 5:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Distribución de clases (entrenamiento): Counter({2: 76, 1: 69, 7: 29, 3: 17, 5: 13, 6: 9})
#     Clase de validación: 1
#
# Leave-One-Out Iris Dataset:
#   Número total de iteraciones: 150
#   Iteración 1:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Distribución de clases (entrenamiento): Counter({1: 50, 2: 50, 0: 49})
#     Clase de validación: 0
#   Iteración 2:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Distribución de clases (entrenamiento): Counter({1: 50, 2: 50, 0: 49})
#     Clase de validación: 0
#   Iteración 3:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Distribución de clases (entrenamiento): Counter({1: 50, 2: 50, 0: 49})
#     Clase de validación: 0
#   Iteración 4:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Distribución de clases (entrenamiento): Counter({1: 50, 2: 50, 0: 49})
#     Clase de validación: 0
#   Iteración 5:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Distribución de clases (entrenamiento): Counter({1: 50, 2: 50, 0: 49})
#     Clase de validación: 0
#
# Leave-One-Out Wine Dataset:
#   Número total de iteraciones: 178
#   Iteración 1:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Distribución de clases (entrenamiento): Counter({2: 71, 1: 58, 3: 48})
#     Clase de validación: 1
#   Iteración 2:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Distribución de clases (entrenamiento): Counter({2: 71, 1: 58, 3: 48})
#     Clase de validación: 1
#   Iteración 3:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Distribución de clases (entrenamiento): Counter({2: 71, 1: 58, 3: 48})
#     Clase de validación: 1
#   Iteración 4:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Distribución de clases (entrenamiento): Counter({2: 71, 1: 58, 3: 48})
#     Clase de validación: 1
#   Iteración 5:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Distribución de clases (entrenamiento): Counter({2: 71, 1: 58, 3: 48})
#     Clase de validación: 1

# %%
from classifier import EuclideanClassifier
from check import accuracy_score, confusion_matrix_binary, precision, recall, f1_score

def validate_classifier(classifier, X, y, dataset_name, method, **kwargs):
    """
    Valida un clasificador con diferentes métodos y calcula métricas.

    Args:
        classifier (object): Clasificador a validar.
        X (list): Datos de entrada.
        y (list): Etiquetas.
        dataset_name (str): Nombre del dataset.
        method (str): Método de validación ('holdout', 'kfold', 'loo').
        kwargs: Argumentos adicionales para los métodos de validación.
    """
    print(f"Validando {dataset_name} con {method}...\n")
    
    if method == "holdout":
        # Dividir datos con Hold-Out
        X_train, X_test, y_train, y_test = hold_out(X, y, **kwargs)
        folds = [(X_train, X_test, y_train, y_test)]
    elif method == "kfold":
        # Crear folds con K-Fold Cross-Validation
        folds = k_fold_cross_validation(X, y, **kwargs)
    elif method == "loo":
        # Crear folds con Leave-One-Out
        folds = leave_one_out(X, y)
    else:
        raise ValueError("Método de validación no reconocido.")
    
    total_accuracy = 0
    total_conf_matrix = {"TP": 0, "TN": 0, "FP": 0, "FN": 0}

    for i, (X_train, X_val, y_train, y_val) in enumerate(folds):
        # Entrenar el clasificador
        classifier.fit(X_train, y_train)

        # Realizar predicciones
        y_pred = classifier.predict(X_val)

        # Calcular métricas
        accuracy = accuracy_score(y_val, y_pred)
        conf_matrix = confusion_matrix_binary(y_val, y_pred)
        tp, tn, fp, fn = conf_matrix["TP"], conf_matrix["TN"], conf_matrix["FP"], conf_matrix["FN"]

        # Acumular métricas
        total_accuracy += accuracy
        total_conf_matrix["TP"] += tp
        total_conf_matrix["TN"] += tn
        total_conf_matrix["FP"] += fp
        total_conf_matrix["FN"] += fn

        # Imprimir resultados por fold/iteración
        print(f"  Fold {i + 1 if method != 'loo' else f'Iteración {i + 1}'}:")
        print(f"    Tamaño de entrenamiento: {len(X_train)}, Tamaño de validación: {len(X_val)}")
        print(f"    Accuracy: {accuracy:.4f}")
        print(f"    Matriz de Confusión: {conf_matrix}\n")

    # Calcular métricas finales
    avg_accuracy = total_accuracy / len(folds)
    prec = precision(total_conf_matrix["TP"], total_conf_matrix["FP"])
    rec = recall(total_conf_matrix["TP"], total_conf_matrix["FN"])
    f1 = f1_score(total_conf_matrix["TP"], total_conf_matrix["FP"], total_conf_matrix["FN"])

    print(f"Resultados Finales para {dataset_name} con {method}:")
    print(f"  Accuracy Promedio: {avg_accuracy:.4f}")
    print(f"  Matriz de Confusión Total: {total_conf_matrix}")
    print(f"  Precision: {prec:.4f}")
    print(f"  Recall: {rec:.4f}")
    print(f"  F1-Score: {f1:.4f}\n")

# Instanciar el clasificador
euclidean_classifier = EuclideanClassifier()

# Validar con los tres métodos y datasets
methods = ["holdout", "kfold", "loo"]
datasets = [
    ("Glass Dataset", X_glass, y_glass),
    ("Iris Dataset", X_iris, y_iris),
    ("Wine Dataset", X_wine, y_wine)
]

for method in methods:
    for dataset_name, X, y in datasets:
        if method == "holdout":
            validate_classifier(euclidean_classifier, X, y, dataset_name, method, test_size=0.3, stratify=True)
        elif method == "kfold":
            validate_classifier(euclidean_classifier, X, y, dataset_name, method, k=10)
        elif method == "loo":
            validate_classifier(euclidean_classifier, X, y, dataset_name, method)
# Out:
# Validando Glass Dataset con holdout...
#
#   Fold 1:
#     Tamaño de entrenamiento: 153, Tamaño de validación: 61
#     Accuracy: 0.3443
#     Matriz de Confusión: {'TP': 4, 'TN': 0, 'FP': 0, 'FN': 0}
#
# Resultados Finales para Glass Dataset con holdout:
#   Accuracy Promedio: 0.3443
#   Matriz de Confusión Total: {'TP': 4, 'TN': 0, 'FP': 0, 'FN': 0}
#   Precision: 1.0000
#   Recall: 1.0000
#   F1-Score: 1.0000
#
# Validando Iris Dataset con holdout...
#
#   Fold 1:
#     Tamaño de entrenamiento: 105, Tamaño de validación: 45
#     Accuracy: 0.9333
#     Matriz de Confusión: {'TP': 13, 'TN': 15, 'FP': 0, 'FN': 0}
#
# Resultados Finales para Iris Dataset con holdout:
#   Accuracy Promedio: 0.9333
#   Matriz de Confusión Total: {'TP': 13, 'TN': 15, 'FP': 0, 'FN': 0}
#   Precision: 1.0000
#   Recall: 1.0000
#   F1-Score: 1.0000
#
# Validando Wine Dataset con holdout...
#
#   Fold 1:
#     Tamaño de entrenamiento: 126, Tamaño de validación: 52
#     Accuracy: 0.9038
#     Matriz de Confusión: {'TP': 16, 'TN': 0, 'FP': 0, 'FN': 0}
#
# Resultados Finales para Wine Dataset con holdout:
#   Accuracy Promedio: 0.9038
#   Matriz de Confusión Total: {'TP': 16, 'TN': 0, 'FP': 0, 'FN': 0}
#   Precision: 1.0000
#   Recall: 1.0000
#   F1-Score: 1.0000
#
# Validando Glass Dataset con kfold...
#
#   Fold 1:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.3810
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 2:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.3333
#     Matriz de Confusión: {'TP': 3, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 3:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.2381
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 4:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.2857
#     Matriz de Confusión: {'TP': 3, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 5:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.4762
#     Matriz de Confusión: {'TP': 5, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 6:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.3810
#     Matriz de Confusión: {'TP': 4, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 7:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.3333
#     Matriz de Confusión: {'TP': 4, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 8:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.3810
#     Matriz de Confusión: {'TP': 2, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 9:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.3333
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 10:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.6190
#     Matriz de Confusión: {'TP': 4, 'TN': 0, 'FP': 0, 'FN': 0}
#
# Resultados Finales para Glass Dataset con kfold:
#   Accuracy Promedio: 0.3762
#   Matriz de Confusión Total: {'TP': 27, 'TN': 0, 'FP': 0, 'FN': 0}
#   Precision: 1.0000
#   Recall: 1.0000
#   F1-Score: 1.0000
#
# Validando Iris Dataset con kfold...
#
#   Fold 1:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 0.9333
#     Matriz de Confusión: {'TP': 4, 'TN': 6, 'FP': 0, 'FN': 0}
#
#   Fold 2:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 7, 'FP': 0, 'FN': 0}
#
#   Fold 3:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 0.9333
#     Matriz de Confusión: {'TP': 7, 'TN': 4, 'FP': 0, 'FN': 0}
#
#   Fold 4:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 0.9333
#     Matriz de Confusión: {'TP': 5, 'TN': 3, 'FP': 0, 'FN': 0}
#
#   Fold 5:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 0.9333
#     Matriz de Confusión: {'TP': 3, 'TN': 5, 'FP': 0, 'FN': 0}
#
#   Fold 6:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 0.9333
#     Matriz de Confusión: {'TP': 6, 'TN': 5, 'FP': 0, 'FN': 0}
#
#   Fold 7:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 0.9333
#     Matriz de Confusión: {'TP': 6, 'TN': 5, 'FP': 0, 'FN': 0}
#
#   Fold 8:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 0.9333
#     Matriz de Confusión: {'TP': 4, 'TN': 6, 'FP': 0, 'FN': 0}
#
#   Fold 9:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 0.8000
#     Matriz de Confusión: {'TP': 3, 'TN': 4, 'FP': 0, 'FN': 0}
#
#   Fold 10:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 5, 'TN': 5, 'FP': 0, 'FN': 0}
#
# Resultados Finales para Iris Dataset con kfold:
#   Accuracy Promedio: 0.9333
#   Matriz de Confusión Total: {'TP': 44, 'TN': 50, 'FP': 0, 'FN': 0}
#   Precision: 1.0000
#   Recall: 1.0000
#   F1-Score: 1.0000
#
# Validando Wine Dataset con kfold...
#
#   Fold 1:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 0.9412
#     Matriz de Confusión: {'TP': 5, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 2:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 7, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 3:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 0.9412
#     Matriz de Confusión: {'TP': 5, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 4:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 0.9412
#     Matriz de Confusión: {'TP': 4, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 5:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 10, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 6:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 7, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 7:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 0.8824
#     Matriz de Confusión: {'TP': 7, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 8:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 7, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 9:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 0.9412
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 10:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 4, 'TN': 0, 'FP': 0, 'FN': 0}
#
# Resultados Finales para Wine Dataset con kfold:
#   Accuracy Promedio: 0.9647
#   Matriz de Confusión Total: {'TP': 57, 'TN': 0, 'FP': 0, 'FN': 0}
#   Precision: 1.0000
#   Recall: 1.0000
#   F1-Score: 1.0000
#
# Validando Glass Dataset con loo...
#
#   Fold Iteración 1:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 2:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 3:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 4:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 5:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 6:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 7:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 8:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 9:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 10:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 11:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 12:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 13:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 14:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 15:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 16:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 17:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 18:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 19:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 20:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 21:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 22:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 23:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 24:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 25:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 26:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 27:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 28:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 29:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 30:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 31:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 32:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 33:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 34:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 35:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 36:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 37:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 38:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 39:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 40:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 41:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 42:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 43:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 44:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 45:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 46:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 47:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 48:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 49:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 50:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 51:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 52:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 53:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 54:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 55:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 56:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 57:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 58:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 59:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 60:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 61:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 62:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 63:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 64:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 65:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 66:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 67:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 68:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 69:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 70:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 71:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 72:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 73:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 74:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 75:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 76:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 77:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 78:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 79:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 80:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 81:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 82:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 83:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 84:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 85:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 86:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 87:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 88:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 89:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 90:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 91:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 92:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 93:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 94:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 95:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 96:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 97:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 98:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 99:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 100:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 101:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 102:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 103:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 104:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 105:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 106:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 107:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 108:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 109:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 110:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 111:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 112:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 113:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 114:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 115:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 116:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 117:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 118:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 119:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 120:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 121:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 122:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 123:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 124:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 125:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 126:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 127:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 128:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 129:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 130:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 131:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 132:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 133:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 134:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 135:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 136:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 137:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 138:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 139:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 140:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 141:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 142:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 143:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 144:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 145:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 146:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 147:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 148:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 149:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 150:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 151:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 152:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 153:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 154:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 155:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 156:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 157:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 158:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 159:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 160:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 161:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 162:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 163:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 164:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 165:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 166:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 167:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 168:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 169:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 170:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 171:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 172:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 173:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 174:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 175:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 176:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 177:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 178:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 179:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 180:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 181:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 182:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 183:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 184:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 185:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 186:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 187:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 188:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 189:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 190:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 191:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 192:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 193:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 194:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 195:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 196:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 197:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 198:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 199:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 200:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 201:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 202:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 203:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 204:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 205:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 206:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 207:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 208:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 209:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 210:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 211:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 212:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 213:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 214:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
# Resultados Finales para Glass Dataset con loo:
#   Accuracy Promedio: 0.4486
#   Matriz de Confusión Total: {'TP': 34, 'TN': 0, 'FP': 0, 'FN': 0}
#   Precision: 1.0000
#   Recall: 1.0000
#   F1-Score: 1.0000
#
# Validando Iris Dataset con loo...
#
#   Fold Iteración 1:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 2:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 3:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 4:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 5:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 6:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 7:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 8:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 9:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 10:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 11:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 12:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 13:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 14:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 15:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 16:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 17:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 18:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 19:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 20:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 21:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 22:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 23:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 24:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 25:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 26:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 27:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 28:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 29:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 30:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 31:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 32:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 33:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 34:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 35:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 36:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 37:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 38:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 39:
# ...
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 83:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 84:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 85:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 86:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 87:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 88:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 89:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 90:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 91:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 92:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 93:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 94:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 95:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 96:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 97:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 98:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 99:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 100:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 101:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 102:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 103:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 104:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 105:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 106:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 107:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 108:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 109:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 110:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 111:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 112:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 113:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 114:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 115:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 116:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 117:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 118:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 119:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 120:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 121:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 122:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 123:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 124:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 125:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 126:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 127:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 128:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 129:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 130:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 131:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 132:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 133:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 134:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 135:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 136:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 137:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 138:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 139:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 140:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 141:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 142:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 143:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 144:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 145:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 146:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 147:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 148:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 149:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 150:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 151:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 152:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 153:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 154:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 155:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 156:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 157:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 158:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 159:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 160:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 161:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 162:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 163:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 164:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 165:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 166:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 167:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 168:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 169:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 170:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 171:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 172:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 173:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 174:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 175:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 176:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 177:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 178:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
# Resultados Finales para Wine Dataset con loo:
#   Accuracy Promedio: 0.9719
#   Matriz de Confusión Total: {'TP': 59, 'TN': 0, 'FP': 0, 'FN': 0}
#   Precision: 1.0000
#   Recall: 1.0000
#   F1-Score: 1.0000

# %%
from knn import KNNClassifier
from check import accuracy_score, confusion_matrix_binary, precision, recall, f1_score
from validation import hold_out, k_fold_cross_validation, leave_one_out

def validate_knn(classifier, X, y, dataset_name, method, **kwargs):
    """
    Valida el Clasificador 1NN con diferentes métodos y calcula métricas.

    Args:
        classifier (object): Clasificador a validar.
        X (list): Datos de entrada.
        y (list): Etiquetas.
        dataset_name (str): Nombre del dataset.
        method (str): Método de validación ('holdout', 'kfold', 'loo').
        kwargs: Argumentos adicionales para los métodos de validación.
    """
    print(f"Validando {dataset_name} con {method}...\n")
    
    if method == "holdout":
        # Dividir datos con Hold-Out
        X_train, X_test, y_train, y_test = hold_out(X, y, **kwargs)
        folds = [(X_train, X_test, y_train, y_test)]
    elif method == "kfold":
        # Crear folds con K-Fold Cross-Validation
        folds = k_fold_cross_validation(X, y, **kwargs)
    elif method == "loo":
        # Crear folds con Leave-One-Out
        folds = leave_one_out(X, y)
    else:
        raise ValueError("Método de validación no reconocido.")
    
    total_accuracy = 0
    total_conf_matrix = {"TP": 0, "TN": 0, "FP": 0, "FN": 0}

    for i, (X_train, X_val, y_train, y_val) in enumerate(folds):
        # Entrenar el clasificador
        classifier.fit(X_train, y_train)

        # Realizar predicciones
        y_pred = classifier.predict(X_val)

        # Calcular métricas
        accuracy = accuracy_score(y_val, y_pred)
        conf_matrix = confusion_matrix_binary(y_val, y_pred)
        tp, tn, fp, fn = conf_matrix["TP"], conf_matrix["TN"], conf_matrix["FP"], conf_matrix["FN"]

        # Acumular métricas
        total_accuracy += accuracy
        total_conf_matrix["TP"] += tp
        total_conf_matrix["TN"] += tn
        total_conf_matrix["FP"] += fp
        total_conf_matrix["FN"] += fn

        # Imprimir resultados por fold/iteración
        print(f"  Fold {i + 1 if method != 'loo' else f'Iteración {i + 1}'}:")
        print(f"    Tamaño de entrenamiento: {len(X_train)}, Tamaño de validación: {len(X_val)}")
        print(f"    Accuracy: {accuracy:.4f}")
        print(f"    Matriz de Confusión: {conf_matrix}\n")

    # Calcular métricas finales
    avg_accuracy = total_accuracy / len(folds)
    prec = precision(total_conf_matrix["TP"], total_conf_matrix["FP"])
    rec = recall(total_conf_matrix["TP"], total_conf_matrix["FN"])
    f1 = f1_score(total_conf_matrix["TP"], total_conf_matrix["FP"], total_conf_matrix["FN"])

    print(f"Resultados Finales para {dataset_name} con {method}:")
    print(f"  Accuracy Promedio: {avg_accuracy:.4f}")
    print(f"  Matriz de Confusión Total: {total_conf_matrix}")
    print(f"  Precision: {prec:.4f}")
    print(f"  Recall: {rec:.4f}")
    print(f"  F1-Score: {f1:.4f}\n")

# Instanciar el clasificador 1NN
knn_classifier = KNNClassifier(k=1)

# Validar con los tres métodos y datasets
methods = ["holdout", "kfold", "loo"]
datasets = [
    ("Glass Dataset", X_glass, y_glass),
    ("Iris Dataset", X_iris, y_iris),
    ("Wine Dataset", X_wine, y_wine)
]

for method in methods:
    for dataset_name, X, y in datasets:
        if method == "holdout":
            validate_knn(knn_classifier, X, y, dataset_name, method, test_size=0.3, stratify=True)
        elif method == "kfold":
            validate_knn(knn_classifier, X, y, dataset_name, method, k=10)
        elif method == "loo":
            validate_knn(knn_classifier, X, y, dataset_name, method)
# Out:
# Validando Glass Dataset con holdout...
#
#   Fold 1:
#     Tamaño de entrenamiento: 153, Tamaño de validación: 61
#     Accuracy: 0.6066
#     Matriz de Confusión: {'TP': 11, 'TN': 0, 'FP': 0, 'FN': 0}
#
# Resultados Finales para Glass Dataset con holdout:
#   Accuracy Promedio: 0.6066
#   Matriz de Confusión Total: {'TP': 11, 'TN': 0, 'FP': 0, 'FN': 0}
#   Precision: 1.0000
#   Recall: 1.0000
#   F1-Score: 1.0000
#
# Validando Iris Dataset con holdout...
#
#   Fold 1:
#     Tamaño de entrenamiento: 105, Tamaño de validación: 45
#     Accuracy: 0.9556
#     Matriz de Confusión: {'TP': 15, 'TN': 15, 'FP': 0, 'FN': 0}
#
# Resultados Finales para Iris Dataset con holdout:
#   Accuracy Promedio: 0.9556
#   Matriz de Confusión Total: {'TP': 15, 'TN': 15, 'FP': 0, 'FN': 0}
#   Precision: 1.0000
#   Recall: 1.0000
#   F1-Score: 1.0000
#
# Validando Wine Dataset con holdout...
#
#   Fold 1:
#     Tamaño de entrenamiento: 126, Tamaño de validación: 52
#     Accuracy: 0.9808
#     Matriz de Confusión: {'TP': 17, 'TN': 0, 'FP': 0, 'FN': 0}
#
# Resultados Finales para Wine Dataset con holdout:
#   Accuracy Promedio: 0.9808
#   Matriz de Confusión Total: {'TP': 17, 'TN': 0, 'FP': 0, 'FN': 0}
#   Precision: 1.0000
#   Recall: 1.0000
#   F1-Score: 1.0000
#
# Validando Glass Dataset con kfold...
#
#   Fold 1:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.4286
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 2:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.7619
#     Matriz de Confusión: {'TP': 4, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 3:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.7619
#     Matriz de Confusión: {'TP': 9, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 4:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.7143
#     Matriz de Confusión: {'TP': 3, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 5:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.7619
#     Matriz de Confusión: {'TP': 9, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 6:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.6190
#     Matriz de Confusión: {'TP': 6, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 7:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.7619
#     Matriz de Confusión: {'TP': 4, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 8:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.7619
#     Matriz de Confusión: {'TP': 9, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 9:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.6667
#     Matriz de Confusión: {'TP': 3, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 10:
#     Tamaño de entrenamiento: 193, Tamaño de validación: 21
#     Accuracy: 0.7619
#     Matriz de Confusión: {'TP': 5, 'TN': 0, 'FP': 0, 'FN': 0}
#
# Resultados Finales para Glass Dataset con kfold:
#   Accuracy Promedio: 0.7000
#   Matriz de Confusión Total: {'TP': 53, 'TN': 0, 'FP': 0, 'FN': 0}
#   Precision: 1.0000
#   Recall: 1.0000
#   F1-Score: 1.0000
#
# Validando Iris Dataset con kfold...
#
#   Fold 1:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 0.9333
#     Matriz de Confusión: {'TP': 5, 'TN': 6, 'FP': 0, 'FN': 0}
#
#   Fold 2:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 5, 'TN': 7, 'FP': 0, 'FN': 0}
#
#   Fold 3:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 0.9333
#     Matriz de Confusión: {'TP': 5, 'TN': 4, 'FP': 0, 'FN': 0}
#
#   Fold 4:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 0.9333
#     Matriz de Confusión: {'TP': 6, 'TN': 4, 'FP': 0, 'FN': 0}
#
#   Fold 5:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 5, 'TN': 8, 'FP': 0, 'FN': 0}
#
#   Fold 6:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 0.9333
#     Matriz de Confusión: {'TP': 4, 'TN': 4, 'FP': 0, 'FN': 0}
#
#   Fold 7:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 0.9333
#     Matriz de Confusión: {'TP': 3, 'TN': 6, 'FP': 0, 'FN': 0}
#
#   Fold 8:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 6, 'TN': 4, 'FP': 0, 'FN': 0}
#
#   Fold 9:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 0.9333
#     Matriz de Confusión: {'TP': 4, 'TN': 3, 'FP': 0, 'FN': 0}
#
#   Fold 10:
#     Tamaño de entrenamiento: 135, Tamaño de validación: 15
#     Accuracy: 0.9333
#     Matriz de Confusión: {'TP': 4, 'TN': 4, 'FP': 0, 'FN': 0}
#
# Resultados Finales para Iris Dataset con kfold:
#   Accuracy Promedio: 0.9533
#   Matriz de Confusión Total: {'TP': 47, 'TN': 50, 'FP': 0, 'FN': 0}
#   Precision: 1.0000
#   Recall: 1.0000
#   F1-Score: 1.0000
#
# Validando Wine Dataset con kfold...
#
#   Fold 1:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 7, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 2:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 0.8824
#     Matriz de Confusión: {'TP': 5, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 3:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 5, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 4:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 0.9412
#     Matriz de Confusión: {'TP': 5, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 5:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 0.9412
#     Matriz de Confusión: {'TP': 4, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 6:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 7, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 7:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 0.8824
#     Matriz de Confusión: {'TP': 6, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 8:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 0.8235
#     Matriz de Confusión: {'TP': 3, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 9:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 6, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold 10:
#     Tamaño de entrenamiento: 161, Tamaño de validación: 17
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 8, 'TN': 0, 'FP': 0, 'FN': 0}
#
# Resultados Finales para Wine Dataset con kfold:
#   Accuracy Promedio: 0.9471
#   Matriz de Confusión Total: {'TP': 56, 'TN': 0, 'FP': 0, 'FN': 0}
#   Precision: 1.0000
#   Recall: 1.0000
#   F1-Score: 1.0000
#
# Validando Glass Dataset con loo...
#
#   Fold Iteración 1:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 2:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 3:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 4:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 5:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 6:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 7:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 8:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 9:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 10:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 11:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 12:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 13:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 14:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 15:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 16:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 17:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 18:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 19:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 20:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 21:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 22:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 23:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 24:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 25:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 26:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 27:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 28:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 29:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 30:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 31:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 32:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 33:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 34:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 35:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 36:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 37:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 38:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 39:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 40:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 41:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 42:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 43:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 44:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 45:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 46:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 47:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 48:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 49:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 50:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 51:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 52:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 53:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 54:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 55:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 56:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 57:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 58:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 59:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 60:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 61:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 62:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 63:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 64:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 65:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 66:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 67:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 68:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 69:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 70:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 1, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 71:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 72:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 73:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 74:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 75:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 76:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 77:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 78:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 79:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 80:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 81:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 82:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 83:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 84:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 85:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 86:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 87:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 88:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 89:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 90:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 91:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 92:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 93:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 94:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 95:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 96:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 97:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 98:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 99:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 100:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 101:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 102:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 103:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 104:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 105:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 106:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 107:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 108:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 109:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 110:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 111:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 112:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 113:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 114:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 115:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 116:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 117:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 118:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 119:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 120:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 121:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 122:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 123:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 124:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 125:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 126:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 127:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 128:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 129:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 130:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 131:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 132:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 133:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 134:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 135:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 136:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 137:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 138:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 139:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 140:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 141:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 142:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 143:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 144:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 145:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 146:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 147:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 148:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 149:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 150:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 151:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 152:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 153:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 154:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 155:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 156:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 157:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 158:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 159:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 160:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 161:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 162:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 163:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 164:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 165:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 166:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 167:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 168:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 169:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 170:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 171:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 172:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 173:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 174:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 175:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 176:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 177:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 178:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 179:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 180:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 181:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 182:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 183:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 184:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 185:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 186:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 187:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 188:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 189:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 190:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 191:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 192:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 193:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 194:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 195:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 196:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 197:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 198:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 199:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 200:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 201:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 202:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 203:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 204:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 205:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 206:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 207:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 208:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 209:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 210:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 211:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 212:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 213:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 214:
#     Tamaño de entrenamiento: 213, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
# Resultados Finales para Glass Dataset con loo:
#   Accuracy Promedio: 0.7009
#   Matriz de Confusión Total: {'TP': 53, 'TN': 0, 'FP': 0, 'FN': 0}
#   Precision: 1.0000
#   Recall: 1.0000
#   F1-Score: 1.0000
#
# Validando Iris Dataset con loo...
#
#   Fold Iteración 1:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 2:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 3:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 4:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 5:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 6:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 7:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 8:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 9:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 10:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 11:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 12:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 13:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 14:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 15:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 16:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 17:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 18:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 19:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 20:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 21:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 22:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 23:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 24:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 25:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 26:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 27:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 28:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 29:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 30:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 31:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 32:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 33:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 34:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 35:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 36:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 37:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 38:
#     Tamaño de entrenamiento: 149, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 1, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 39:
# ...
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 83:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 84:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 85:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 86:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 87:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 88:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 89:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 90:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 91:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 92:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 93:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 94:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 95:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 96:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 97:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 98:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 99:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 100:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 101:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 102:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 103:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 104:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 105:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 106:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 107:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 108:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 109:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 110:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 111:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 112:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 113:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 114:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 115:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 116:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 117:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 118:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 119:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 120:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 121:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 122:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 123:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 124:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 0.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 125:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 126:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 127:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 128:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 129:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 130:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 131:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 132:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 133:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 134:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 135:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 136:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 137:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 138:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 139:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 140:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 141:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 142:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 143:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 144:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 145:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 146:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 147:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 148:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 149:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 150:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 151:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 152:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 153:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 154:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 155:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 156:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 157:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 158:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 159:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 160:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 161:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 162:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 163:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 164:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 165:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 166:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 167:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 168:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 169:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 170:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 171:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 172:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 173:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 174:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 175:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 176:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 177:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
#   Fold Iteración 178:
#     Tamaño de entrenamiento: 177, Tamaño de validación: 1
#     Accuracy: 1.0000
#     Matriz de Confusión: {'TP': 0, 'TN': 0, 'FP': 0, 'FN': 0}
#
# Resultados Finales para Wine Dataset con loo:
#   Accuracy Promedio: 0.9494
#   Matriz de Confusión Total: {'TP': 59, 'TN': 0, 'FP': 0, 'FN': 0}
#   Precision: 1.0000
#   Recall: 1.0000
#   F1-Score: 1.0000
